# %%
###part 2

import numpy as np
import pandas as pd
from pydataset import data


# c1 copy the DatFrames:
users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users

roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles

#2 right join will make sure all values in id column are filled
roles.merge(users, how = 'right') #right join justs lists
#the table that is in the parenthesis

#3 outer join, puts all ids under one column and name under one column
roles.merge(users,how = 'outer')
# Out:
#    id       name  role_id
# 0   1      admin      NaN
# 1   2     author      NaN
# 2   3   reviewer      NaN
# 3   4  commenter      NaN
# 4   1        bob      1.0
# 5   2        joe      2.0
# 6   3      sally      3.0
# 7   4       adam      3.0
# 8   5       jane      NaN
# 9   6       mike      NaN

# %%
roles_nfk = roles[['name']]
roles_nfk
users_nfk = users[['name','id']]

# %%
users_nfk.merge(roles_nfk, how='outer') ##this is what you get when you drop foregin keys
# Out:
#         name   id
# 0        bob  1.0
# 1        joe  2.0
# 2      sally  3.0
# 3       adam  4.0
# 4       jane  5.0
# 5       mike  6.0
# 6      admin  NaN
# 7     author  NaN
# 8   reviewer  NaN
# 9  commenter  NaN

# %%
mpg = data('mpg')

# %%
mpg # 234 rows and 11 columns
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
# 234  midsize
#
# [234 rows x 11 columns]

# %%
mpg = mpg.rename(columns = {'cty':'city', 'hwy':'highway', 'displ':'display','cyl':'cycle',\
                            'trans':'transmission','drv':'drive'})

# %%
mpg.describe() #summary statistics
# Out:
#           display         year       cycle        city     highway
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
mpg.manufacturer.nunique() ##number of unique manufacturers in the mpg DF
# Out:
# 15

# %%
mpg.model.nunique() ##number of different models
# Out:
# 38

# %%
mpg['milage_difference'] = mpg.highway - mpg.city ##adding milage difference

# %%
mpg['average_milage'] = (mpg.highway + mpg.city)/2 ##adding average milwage

# %%
mpg['is_automatic'] = mpg.transmission.str.contains('auto') == True
mpg['is_automatic'] = mpg['is_automatic'].replace({True: 'automatic', False: 'manual'})

# %%
mpg
# Out:
#     manufacturer   model  display  year  cycle transmission drive  city  \
# 1           audi      a4      1.8  1999      4     auto(l5)     f    18
# 2           audi      a4      1.8  1999      4   manual(m5)     f    21
# 3           audi      a4      2.0  2008      4   manual(m6)     f    20
# 4           audi      a4      2.0  2008      4     auto(av)     f    21
# 5           audi      a4      2.8  1999      6     auto(l5)     f    16
# ..           ...     ...      ...   ...    ...          ...   ...   ...
# 230   volkswagen  passat      2.0  2008      4     auto(s6)     f    19
# 231   volkswagen  passat      2.0  2008      4   manual(m6)     f    21
# 232   volkswagen  passat      2.8  1999      6     auto(l5)     f    16
# 233   volkswagen  passat      2.8  1999      6   manual(m5)     f    18
# 234   volkswagen  passat      3.6  2008      6     auto(s6)     f    17
#
#      highway fl    class  milage_difference  average_milage is_automatic
# 1         29  p  compact                 11            23.5    automatic
# 2         29  p  compact                  8            25.0       manual
# 3         31  p  compact                 11            25.5       manual
# 4         30  p  compact                  9            25.5    automatic
# 5         26  p  compact                 10            21.0    automatic
# ..       ... ..      ...                ...             ...          ...
# 230       28  p  midsize                  9            23.5    automatic
# 231       29  p  midsize                  8            25.0       manual
# 232       26  p  midsize                 10            21.0    automatic
# 233       26  p  midsize                  8            22.0       manual
# 234       26  p  midsize                  9            21.5    automatic
#
# [234 rows x 14 columns]

# %%
mpg.sort_values('is_automatic')
# Out:
#     manufacturer                model  display  year  cycle transmission  \
# 1           audi                   a4      1.8  1999      4     auto(l5)
# 131   land rover          range rover      4.0  1999      8     auto(l4)
# 132   land rover          range rover      4.2  2008      8     auto(s6)
# 133   land rover          range rover      4.4  2008      8     auto(s6)
# 134   land rover          range rover      4.6  1999      8     auto(l4)
# ..           ...                  ...      ...   ...    ...          ...
# 142       nissan               altima      2.4  1999      4   manual(m5)
# 56         dodge    dakota pickup 4wd      5.2  1999      8   manual(m5)
# 65         dodge  ram 1500 pickup 4wd      4.7  2008      8   manual(m6)
# 160       subaru         forester awd      2.5  1999      4   manual(m5)
# 117      hyundai              tiburon      2.0  1999      4   manual(m5)
#
#     drive  city  highway fl       class  milage_difference  average_milage  \
# 1       f    18       29  p     compact                 11            23.5
# 131     4    11       15  p         suv                  4            13.0
# 132     4    12       18  r         suv                  6            15.0
# 133     4    12       18  r         suv                  6            15.0
# 134     4    11       15  p         suv                  4            13.0
# ..    ...   ...      ... ..         ...                ...             ...
# 142     f    21       29  r     compact                  8            25.0
# 56      4    11       17  r      pickup                  6            14.0
# 65      4    12       16  r      pickup                  4            14.0
# 160     4    18       25  r         suv                  7            21.5
# 117     f    19       29  r  subcompact                 10            24.0
#
#     is_automatic
# 1      automatic
# 131    automatic
# 132    automatic
# 133    automatic
# 134    automatic
# ..           ...
# 142       manual
# 56        manual
# 65        manual
# 160       manual
# 117       manual
#
# [234 rows x 14 columns]

# %%
# df.groupby(['column_name', 'other_column']).column_name_you_want_to_perform_functions\
#.agg(['list_of_operations','mean'])
mpg.groupby(['is_automatic']).average_milage.agg(['mean'])


##manual gets better mpg
# Out:
#                    mean
# is_automatic
# automatic     19.130573
# manual        22.227273

# %%
import env

# %%
env.username
# Out:
# 'noether_2026'

# %%
### part 1 function get_db_url
import os
def get_db_url(db, env_file=os.path.exists('env.py')):
    '''
    return a formatted string containing username, password, host
    and database for connecting to the mySQL server
    and the database indicated.
    env_file checks to see if the env.py exists in cwd
    '''
    if env_file:
        username, password, host = (env.username, env.password, env.host)
        return f'mysql+pymysql://{username}:{password}@{host}/{db}'
    else:
        return 'hello, you need a username and password to get in!'

# %%
url = get_db_url('employees')

# %%
query = 'select dept_name from departments;'

# %%
df = pd.read_sql(query, url) ##5a this is the error message that you
#get when you type in a bad url, access denied

## error bad URL: access denied
## error when bad query: Unknown
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/9m/3m9g9yzs77j2m_79z47fjdr00000gq/T/ipykernel_4117/681673663.py in <module>
# ----> 1 df = pd.read_sql(query, url) ##5a this is the error message that you
#       2 #get when you type in a bad url, access denied
#       3
#       4 ## error bad URL: access denied
#       5 ## error when bad query: Unknown
#
# NameError: name 'pd' is not defined

# %%
query1 = 'select * from employees limit 10'

# %%
query2 = 'select * from titles limit 10'

# %%
df1 = pd.read_sql(query1, url)  ##question 7, 300024 rows and 6 columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/9m/3m9g9yzs77j2m_79z47fjdr00000gq/T/ipykernel_4117/1295180455.py in <module>
# ----> 1 df1 = pd.read_sql(query1, url)  ##question 7, 300024 rows and 6 columns
#
# NameError: name 'pd' is not defined

# %%
df2 = pd.read_sql(query2, url) ##443308 rows and 4 columns, yeah,
# it is what I expected.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/9m/3m9g9yzs77j2m_79z47fjdr00000gq/T/ipykernel_4117/1685288162.py in <module>
# ----> 1 df2 = pd.read_sql(query2, url) ##443308 rows and 4 columns, yeah,
#       2 # it is what I expected.
#
# NameError: name 'pd' is not defined

# %%
df1.describe() #summary statistics question 8
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/9m/3m9g9yzs77j2m_79z47fjdr00000gq/T/ipykernel_4117/4238073693.py in <module>
# ----> 1 df1.describe() #summary statistics question 8
#
# NameError: name 'df1' is not defined

# %%
df2.describe() # question 8, summary statistics
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/9m/3m9g9yzs77j2m_79z47fjdr00000gq/T/ipykernel_4117/2683112836.py in <module>
# ----> 1 df2.describe() # question 8, summary statistics
#
# NameError: name 'df2' is not defined

# %%
df2.title.nunique() ## question 9, 7 different titles
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/9m/3m9g9yzs77j2m_79z47fjdr00000gq/T/ipykernel_4117/424751028.py in <module>
# ----> 1 df2.title.nunique() ## question 9, 7 different titles
#
# NameError: name 'df2' is not defined

# %%
print(df2.to_date.min()) ##1985-03-01 This is the oldest date #question10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/9m/3m9g9yzs77j2m_79z47fjdr00000gq/T/ipykernel_4117/884569848.py in <module>
# ----> 1 print(df2.to_date.min()) ##1985-03-01 This is the oldest date #question10
#
# NameError: name 'df2' is not defined

# %%
query = '''select to_date 
            from titles 
            where to_date <= now() order by to_date DESC limit 5'''

# %%
recent_date = pd.read_sql(query, url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/9m/3m9g9yzs77j2m_79z47fjdr00000gq/T/ipykernel_4117/686589509.py in <module>
# ----> 1 recent_date = pd.read_sql(query, url)
#
# NameError: name 'pd' is not defined

# %%
recent_date #the most recent actual date is 2002-08-01
# Out:
#       to_date
# 0  2002-08-01
# 1  2002-08-01
# 2  2002-08-01
# 3  2002-08-01
# 4  2002-08-01

# %%
##part 3

# %%
url = get_db_url('chipotle')

# %%
query = ('select quantity, item_name, item_price from orders')

# %%
query = ('select quantity, item_name, item_price from orders')
chipotle_df = pd.read_sql(query, url)

# %%
from useful_functions import convert_dollars_to_float

# %%
chipotle_df
# Out:
#       quantity                              item_name item_price
# 0            1           Chips and Fresh Tomato Salsa     $2.39
# 1            1                                   Izze     $3.39
# 2            1                       Nantucket Nectar     $3.39
# 3            1  Chips and Tomatillo-Green Chili Salsa     $2.39
# 4            2                           Chicken Bowl    $16.98
# ...        ...                                    ...        ...
# 4617         1                          Steak Burrito    $11.75
# 4618         1                          Steak Burrito    $11.75
# 4619         1                     Chicken Salad Bowl    $11.25
# 4620         1                     Chicken Salad Bowl     $8.75
# 4621         1                     Chicken Salad Bowl     $8.75
#
# [4622 rows x 3 columns]

# %%
chipotle_df['item_price_float'] = convert_dollars_to_float(chipotle_df.item_price)

# %%
chipotle_df['order_total'] = chipotle_df.quantity * chipotle_df.item_price_float

# %%
total_order = chipotle_df.drop(columns = ['item_price']) ##2 column order_total
#gives total price

# %%
total_order
# Out:
#       quantity                              item_name  order_total  \
# 0            1           Chips and Fresh Tomato Salsa         2.39
# 1            1                                   Izze         3.39
# 2            1                       Nantucket Nectar         3.39
# 3            1  Chips and Tomatillo-Green Chili Salsa         2.39
# 4            2                           Chicken Bowl        33.96
# ...        ...                                    ...          ...
# 4617         1                          Steak Burrito        11.75
# 4618         1                          Steak Burrito        11.75
# 4619         1                     Chicken Salad Bowl        11.25
# 4620         1                     Chicken Salad Bowl         8.75
# 4621         1                     Chicken Salad Bowl         8.75
#
#       item_price_float
# 0                 2.39
# 1                 3.39
# 2                 3.39
# 3                 2.39
# 4                16.98
# ...                ...
# 4617             11.75
# 4618             11.75
# 4619             11.25
# 4620              8.75
# 4621              8.75
#
# [4622 rows x 4 columns]

# %%
sum_of_items = total_order.groupby('item_name').quantity.agg(['sum'])

# %%
sum_of_items.sort_values('sum').tail(3) #3 most popular items
# Out:
#                      sum
# item_name
# Chips and Guacamole  506
# Chicken Burrito      591
# Chicken Bowl         761

# %%
sum_of_revenue_each_item = total_order.groupby('item_name').\
order_total.agg(['sum'])

# %%
sum_of_revenue_each_item.sort_values('sum').tail(1)
#4 Chicken Bowl is the item that produced the most
# Out:
#                   sum
# item_name
# Chicken Bowl  8044.63

# %%
url = get_db_url('employees')
query = ('select * from employees join titles')

# %%
df ## 5 this is joining the employees and titles df together

# %%
df.sort_values(['title', 'from_date'])
# Out:
#     emp_no  birth_date   first_name     last_name gender   hire_date  emp_no  \
# 0    19551  1960-10-30      Radhika       Solares      M  1986-10-19   10001
# 1    19550  1957-10-22      Pranjal         Denis      M  1992-08-27   10001
# 2    19549  1954-11-07          Uli      Muhlberg      M  1990-07-26   10001
# 3    19548  1961-11-04       Chriss     Kowalchuk      M  1988-11-27   10001
# 4    19547  1959-02-27     Xiaoshan   Limongiello      M  1995-12-28   10001
# 5    19546  1952-03-19         Kwan          Penz      M  1987-07-21   10001
# 6    19545  1961-01-01          Gen       Lanteri      F  1991-12-02   10001
# 7    19544  1953-03-31      Itzchak         Comte      M  1989-05-10   10001
# 8    19543  1954-01-03     Chaitali          Perl      M  1988-08-02   10001
# 9    19542  1962-10-16      Xiaoqiu         Biron      M  1990-07-22   10001
# 10   19541  1964-02-11      JiYoung      Werthner      F  1985-05-15   10001
# 11   19540  1963-05-19      Tsvetan      Maliniak      M  1989-05-14   10001
# 12   19539  1962-04-30      Premsyl        Ramsak      M  1993-03-07   10001
# 13   19538  1963-03-28      Rasikan       Angelov      M  1986-08-08   10001
# 14   19537  1963-07-25         Shem        Uludag      F  1989-06-10   10001
# 15   19536  1960-05-12        Kolar         Hmelo      M  1989-01-12   10001
# 16   19535  1962-03-24      Ottavia      Pintelas      F  1994-05-03   10001
# 17   19534  1955-04-11       Satosi       Moehrke      M  1996-07-10   10001
# 18   19533  1953-06-25   Jacqueline   Grospietsch      M  1989-04-16   10001
# 19   19532  1957-04-01     Mizuhito        Gimbel      F  1994-03-13   10001
# 20   19531  1956-04-21      Phillip         Picel      M  1986-04-28   10001
# 21   19530  1953-12-26        Barry        Dratva      M  1997-09-02   10001
# 22   19529  1961-01-01         Arun      Minakawa      M  1988-03-10   10001
# 23   19528  1957-10-17        Pohua     Nooteboom      F  1994-10-27   10001
# 24   19527  1964-09-10          Ulf       Chvatal      F  1991-03-08   10001
# 25   19526  1959-09-17      Florina     Barbanera      M  1987-08-15   10001
# 26   19525  1960-09-18       Nitsan    Lieberherr      F  1987-06-25   10001
# 27   19524  1962-01-21        Emran         Rosis      F  1995-12-01   10001
# 28   19523  1957-01-23     Froduald         Czaja      M  1985-06-18   10001
# 29   19522  1957-04-12       Rafail   Cappelletti      M  1988-11-25   10001
# 30   19521  1962-04-01          Uzi      Cunliffe      F  1995-03-09   10001
# 31   19520  1953-12-29        Weiye  Ossenbruggen      M  1991-07-01   10001
# 32   19519  1964-02-28         Duke      Ratzlaff      F  1985-08-10   10001
# 79  Senior Engineer  1986-06-26  9999-01-01
# 80  Senior Engineer  1986-06-26  9999-01-01
# 81  Senior Engineer  1986-06-26  9999-01-01
# 82  Senior Engineer  1986-06-26  9999-01-01
# 83  Senior Engineer  1986-06-26  9999-01-01
# 84  Senior Engineer  1986-06-26  9999-01-01
# 85  Senior Engineer  1986-06-26  9999-01-01
# 86  Senior Engineer  1986-06-26  9999-01-01
# 87  Senior Engineer  1986-06-26  9999-01-01
# 88  Senior Engineer  1986-06-26  9999-01-01
# 89  Senior Engineer  1986-06-26  9999-01-01
# 90  Senior Engineer  1986-06-26  9999-01-01
# 91  Senior Engineer  1986-06-26  9999-01-01
# 92  Senior Engineer  1986-06-26  9999-01-01
# 93  Senior Engineer  1986-06-26  9999-01-01
# 94  Senior Engineer  1986-06-26  9999-01-01
# 95  Senior Engineer  1986-06-26  9999-01-01
# 96  Senior Engineer  1986-06-26  9999-01-01
# 97  Senior Engineer  1986-06-26  9999-01-01
# 98  Senior Engineer  1986-06-26  9999-01-01
# 99  Senior Engineer  1986-06-26  9999-01-01

# %%
url = get_db_url('employees')
query = ('''select title, max(hire_date) from employees 
join titles using(emp_no) 
group by title''')

# %%
employee_hire_date = pd.read_sql(query, url)

# %%
employee_hire_date #6 this shows the hire date 
#of the most recent employee hired with the given title
# Out:
#                 title max(hire_date)
# 0     Senior Engineer     2000-01-01
# 1               Staff     2000-01-12
# 2            Engineer     2000-01-28
# 3        Senior Staff     2000-01-13
# 4  Assistant Engineer     1999-12-24
# 5    Technique Leader     1999-12-31
# 6             Manager     1992-02-05

# %%
## 7

query = ('''select dept_emp.dept_no, titles.title 
from dept_emp join 
titles using(emp_no);''')

# %%
count_title_per_dept = pd.read_sql(query, url)

# %%
count_title_per_dept
# Out:
#        dept_no         title
# 0         d001  Senior Staff
# 1         d001         Staff
# 2         d001         Staff
# 3         d001  Senior Staff
# 4         d001         Staff
# ...        ...           ...
# 489898    d009         Staff
# 489899    d009         Staff
# 489900    d009  Senior Staff
# 489901    d009         Staff
# 489902    d009         Staff
#
# [489903 rows x 2 columns]

# %%
cross_tab = pd.crosstab(count_title_per_dept.dept_no, \
                        count_title_per_dept.title,\
                       margins = True)

# %%
cross_tab ##8 this gives the table with
#the counts of title per department
# Out:
# title    Assistant Engineer  Engineer  Manager  Senior Engineer  Senior Staff  \
# dept_no
# d001                      0         0        2                0         13940
# d002                      0         0        2                0         12139
# d003                      0         0        2                0         12274
# d004                   6445     49649        4            42205          1270
# d005                   7769     58135        2            49326          1247
# d006                   1831     13852        4            11864             0
# d007                      0         0        2                0         36191
# d008                    378      2986        2             2570         11637
# d009                    298      2362        4             2027         13925
# All                   16721    126984       24           107992        102623
#
# title     Staff  Technique Leader     All
# dept_no
# d001      16196                 0   30138
# d002      13929                 0   26070
# d003      14342                 0   26618
# d004       1478              6557  107608
# d005       1424              7683  125586
# d006          0              1795   29346
# d007      41808                 0   78001
# d008      13495               393   31461
# d009      16150               309   35075
# All      118822             16737  489903
