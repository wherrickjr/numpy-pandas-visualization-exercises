# %%
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %%
pokemon = pd.read_csv('pokemon_data.csv')

# %%
pokemon
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# ## Discussion
#
#
# #### 1. What is a dataframe?
# A data frame is another name for table
#
# #### 2. What information can we obtain about a dataframe?
# indices, column names, column value types, shape
#
# #### 3. How have we interacted with a dataframe?
# add/drop/rename columns, mask, filter, value_sort

# %%
##1
pokemon
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
pokemon.dtypes #question 2
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
pokemon.info() #question 2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
pokemon.describe() #question 2
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
pokemon.shape #question 2
# Out:
# (800, 12)

# %% [markdown]
# ## Highest and lowest values

# %%
pokemon.HP.max()
# Out:
# 255

# %% [markdown]
# # question 1: highest hp is 255

# %%
pokemon[pokemon['HP'] == 255]
# Out:
#        #     Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 261  242  Blissey  Normal    NaN  255      10       10       75      135
#
#      Speed  Generation  Legendary
# 261     55           2      False

# %% [markdown]
#  # question 2: Blissey has the highest HP value

# %%
pokemon['Type 1'].nunique()
# Out:
# 721

# %% [markdown]
# ## Question 3: There are 18 unique Type 1s

# %%
ghost = pokemon[pokemon['Type 2'] == 'Ghost']

# %%
ghost['#'].nunique()
# Out:
# 12

# %% [markdown]
# # Question 4: there are 12 pokemon with Type 2 Ghost

# %%
pokemon['#'].nunique()
# Out:
# 721

# %%
(12/721) * 100
# Out:
# 1.6643550624133148

# %% [markdown]
# # Question 5: 1.66% of pokemon have Type 2 Ghost

# %%
more_attack = pokemon[pokemon['Attack'] > pokemon['Defense']]

# %%
more_attack['#'].nunique()
# Out:
# 397

# %% [markdown]
# # Question 6: 397 pokemon have higher attack than defense

# %%
pokemon['Total'] = (pokemon['HP']\
                    + pokemon['Attack']\
                    + pokemon['Defense']\
                    + pokemon['Sp. Atk'] + \
                    pokemon['Sp. Def'] + pokemon['Speed'])

# %%
type2 = pokemon[pokemon['Type 2'] == 'Psychic']

# %%
type2.Total.max()
# Out:
# 700

# %% [markdown]
#  ## Question 7: Highest total value of Psychic Type 2

# %%
grass_or_rock = pokemon[(pokemon['Type 1'] == 'Grass') | \
                        (pokemon['Type 1'] == 'Rock')]

# %%
grass_or_rock.Speed.min()
# Out:
# 10

# %% [markdown]
# ## Question 8: Lowest Speed for Grass or Rock

# %%
pokemon.groupby('Generation').Speed.agg(['mean'])
# Out:
#                  mean
# Generation
# 1           72.584337
# 2           61.811321
# 3           66.925000
# 4           71.338843
# 5           68.078788
# 6           66.439024

# %% [markdown]
# ## Question 9: above DF calculates average speed by gen

# %%
pokemon.columns= pokemon.columns.str.lower()

# %%
pokemon
# Out:
#        #                   name   type 1  type 2  hp  attack  defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      sp. atk  sp. def  speed  generation  legendary  total
# 0         65       65     45           1      False    318
# ...

# %% [markdown]
#  ## Question 10: lowercase all column names

# %%
pokemon.rename(columns =\
               {'sp. def': 'special defense', 'sp. atk': 'special attack'})
# Out:
#        #                   name   type 1  type 2  hp  attack  defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      special attack  special defense  speed  generation  legendary  total
# ...

# %% [markdown]
#  ## Question 11 and 12 are reflected on DF above

# %%
pokemon['attack_defense'] = pokemon['attack']-pokemon['defense']

# %%
pokemon['sp. atk diff'] = pokemon['sp. atk'] - pokemon['sp. def']

# %%
pokemon['attack_defense'].max()
# Out:
# 160

# %%
pokemon['sp. atk diff'].max()
# Out:
# 160

# %%
attackvdefense = pokemon[pokemon['attack_defense'] == 160]
attackvdefense
# Out:
#        #                name   type 1 type 2  hp  attack  defense  sp. atk  \
# 429  386  DeoxysAttack Forme  Psychic    NaN  50     180       20      180
#
#      sp. def  speed  generation  legendary  total  attack_defense  \
# 429       20    150           3       True    600             160
#
#      sp. atk diff
# 429           160

# %%
spattackvspdefense = pokemon[pokemon['sp. atk diff'] == 160]
spattackvspdefense
# Out:
#        #                name   type 1 type 2  hp  attack  defense  sp. atk  \
# 429  386  DeoxysAttack Forme  Psychic    NaN  50     180       20      180
#
#      sp. def  speed  generation  legendary  total  attack_defense  \
# 429       20    150           3       True    600             160
#
#      sp. atk diff
# 429           160

# %% [markdown]
#  ## Question 13: Deoxys has the greatest difference in
#  ## attack and defense and sp. attack and sp. defense

# %%
Rock_and_Fairy = pokemon[(pokemon['type 1'] == 'Rock') & \
                        (pokemon['type 2'] == 'Fairy')]

# %%
Rock_and_Fairy['#'].nunique()
# Out:
# 2

# %% [markdown]
# ## Question 14: there are 2 pokemon with Type 1 Rock
# ## and Type 2 Fairy

# %%
alphapoke = pokemon.sort_values('name')

# %%
alphapoke.tail()
# Out:
#        #              name  type 1  type 2   hp  attack  defense  sp. atk  \
# 632  571           Zoroark    Dark     NaN   60     105       60      120
# 631  570             Zorua    Dark     NaN   40      65       40       80
# 46    41             Zubat  Poison  Flying   40      45       35       30
# 695  634          Zweilous    Dark  Dragon   72      85       70       65
# 794  718  Zygarde50% Forme  Dragon  Ground  108     100      121       81
#
#      sp. def  speed  generation  legendary  total  attack_defense  \
# 632       60    105           5      False    510              45
# 631       40     65           5      False    330              25
# 46        40     55           1      False    245              10
# 695       70     58           5      False    420              15
# 794       95     95           6       True    600             -21
#
#      sp. atk diff
# 632            60
# 631            40
# 46            -10
# 695            -5
# 794           -14

# %% [markdown]
# ## Question 15: Zygarde50% Forme is the pokemon
# ## that appears last alphabetically
