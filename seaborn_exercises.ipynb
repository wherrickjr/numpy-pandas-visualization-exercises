# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.histplot(data = iris, x="petal_length")
plt.show() ##this is what the distribution of petal lengths looks like

# %%
plt.show(sns.relplot(data = iris, x="petal_length",\
                     y = "petal_width", hue = "species"))
## question 2, yes, there is a strong positive correlation

# %%
plt.show(sns.relplot(data = iris, x="sepal_length", y = \
                     "sepal_width", hue = \
                     "species"))
##3 it would not be reasonable to guess species based on sepal 
#width/length

##4 using petal length/width would give a fairly accurate species
#prediction

# %%
ans = sns.load_dataset('anscombe')

# %%
ans
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
datasetI = ans[ans["dataset"] == 'I']

# %%
datasetII = ans[ans["dataset"] == 'II']

# %%
datasetIII = ans[ans["dataset"] == 'III']

# %%
datasetIV = ans[ans["dataset"] == 'IV']

# %%
datasetI.describe() ##question 1 part 2
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031568
# min     4.000000   4.260000
# 25%     6.500000   6.315000
# 50%     9.000000   7.580000
# 75%    11.500000   8.570000
# max    14.000000  10.840000

# %%
datasetII.describe()##question 1 part 2
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031657
# min     4.000000   3.100000
# 25%     6.500000   6.695000
# 50%     9.000000   8.140000
# 75%    11.500000   8.950000
# max    14.000000   9.260000

# %%
datasetIII.describe()##question 1 part 2
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500000
# std     3.316625   2.030424
# min     4.000000   5.390000
# 25%     6.500000   6.250000
# 50%     9.000000   7.110000
# 75%    11.500000   7.980000
# max    14.000000  12.740000

# %%
datasetIV.describe()##question 1 part 2
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.030579
# min     8.000000   5.250000
# 25%     8.000000   6.170000
# 50%     8.000000   7.040000
# 75%     8.000000   8.190000
# max    19.000000  12.500000

# %%
plt.show(sns.relplot(data = ans, x = "x", y = "y", col = "dataset"))

##part 2 question 1

# %%
from pydataset import data

# %%
yo = data('InsectSprays')
yo.head()
# Out:
#    count spray
# 1     10     A
# 2      7     A
# 3     20     A
# 4     14     A
# 5     14     A

# %%
yo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72 entries, 1 to 72
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   count   72 non-null     int64
#  1   spray   72 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 1.7+ KB

# %%
sns.boxplot(data=df, \
            x= yo["count"])
# Out:
# <AxesSubplot:xlabel='count'>

# %%
data('InsectSprays', show_doc = True)
yo.spray.unique()
# Out:
# InsectSprays
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Effectiveness of Insect Sprays
#
# ### Description
#
# The counts of insects in agricultural experimental units treated with
# different insecticides.
#
# ### Usage
#
#     InsectSprays
#
# ### Format
#
# A data frame with 72 observations on 2 variables.
#
# [,1]
#
# count
#
# numeric
#
# Insect count
#
# [,2]
#
# spray
#
# factor
#
# The type of spray
#
# ### Source
#
# Beall, G., (1942) The Transformation of data from entomological field
# experiments, _Biometrika_, **29**, 243–262.
#
# ### References
#
# McNeil, D. (1977) _Interactive Data Analysis_. New York: Wiley.
#
# ### Examples
#
#     require(stats); require(graphics)
#     boxplot(count ~ spray, data = InsectSprays,
#             xlab = "Type of spray", ylab = "Insect count",
#             main = "InsectSprays data", varwidth = TRUE, col = "lightgray")
#     fm1 <- aov(count ~ spray, data = InsectSprays)
# ...

# %%
A = yo[yo["spray"] == "A"]
B = yo[yo["spray"] == "B"]
C = yo[yo["spray"] == 'C']
D = yo[yo["spray"] == 'D']
E = yo[yo["spray"] == 'E']
F = yo[yo["spray"] == 'F']

# %%
plt.show(sns.boxplot(data = yo, x = "count", y = "spray"))

# %% [markdown]
# # above shows the box plot of each spray and their count

# %%
data('swiss')
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
# Porrentruy         76.1         35.3            9          7     90.57
# Broye              83.8         70.2           16          7     92.85
# Glane              92.4         67.8           14          8     97.16
# Gruyere            82.4         53.3           12          7     97.67
# Sarine             82.9         45.2           16         13     91.38
# Veveyse            87.1         64.5           14          6     98.61
# Aigle              64.1         62.0           21         12      8.52
# ...

# %%
swiss = data('swiss')
swiss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47 entries, Courtelary to Rive Gauche
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Fertility         47 non-null     float64
#  1   Agriculture       47 non-null     float64
#  2   Examination       47 non-null     int64
#  3   Education         47 non-null     int64
#  4   Catholic          47 non-null     float64
#  5   Infant.Mortality  47 non-null     float64
# dtypes: float64(4), int64(2)
# memory usage: 2.6+ KB

# %% [markdown]
# ## I would say that if a city has more than 90% catholic, they would be considered catholic

# %%
swiss['is_catholic'] = swiss['Catholic'] > 90

# %%
swiss
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
# Porrentruy         76.1         35.3            9          7     90.57
# Broye              83.8         70.2           16          7     92.85
# Glane              92.4         67.8           14          8     97.16
# Gruyere            82.4         53.3           12          7     97.67
# Sarine             82.9         45.2           16         13     91.38
# Veveyse            87.1         64.5           14          6     98.61
# Aigle              64.1         62.0           21         12      8.52
# ...

# %%
plt.show(sns.relplot(data = swiss, x="Catholic", y = \
                     "Fertility"))

# %% [markdown]
# ## The scatter plot above shows a weak positive correlation between percent of Catholicism and Fertility. This indicates that the more catholic a city is, the more likely they are to have a higher fertility rate.
#
# ## I would not say that one influences the other.

# %%
plt.show(sns.relplot(data = swiss, x="Examination", y = \
                     "Fertility"))

# %%
plt.suptitle('Comparing variables against fertility')


sns.relplot(data=swiss, x= "Agriculture", y='Fertility')
plt.title('Agriculture')

sns.relplot(data=swiss, x= "Education", y='Fertility')
plt.title('Education')

sns.relplot(data=swiss, x= "Examination", y='Fertility')
plt.title('Examination')

sns.relplot(data=swiss, x= "Infant.Mortality", y='Fertility')
plt.title('Infant.Mortality')

sns.relplot(data=swiss, x= "Catholic", y='Fertility')
plt.title('Agriculture')
# Out:
# Text(0.5, 1.0, 'Agriculture')

# %% [markdown]
# ## the variable that has the highest positive correlation with fertility is Infant.Mortality and the highest negative is Examination

# %%
sleep = data('sleepstudy')

# %%
sleep
# Out:
#      Reaction  Days  Subject
# 1    249.5600     0      308
# 2    258.7047     1      308
# 3    250.8006     2      308
# 4    321.4398     3      308
# 5    356.8519     4      308
# ..        ...   ...      ...
# 176  329.6076     5      372
# 177  334.4818     6      372
# 178  343.2199     7      372
# 179  369.1417     8      372
# 180  364.1236     9      372
#
# [180 rows x 3 columns]

# %%
sns.lineplot(data = sleep, x = 'Subject', y ='Reaction')
# Out:
# <AxesSubplot:xlabel='Subject', ylabel='Reaction'>

# %% [markdown]
#  ## above is question number 5
