# %%
### Characteristics

# %%
### Import Libraries
import pandas as pd
import numpy as np

# %%
#Set the value used to generate random numbers
np.random.seed(123)

# %%
# Create a list with various student names
students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# %%
# Generate random scores for each student in 3 subjects
# Use random integers from numpy

#Math
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

# %%
#created datafram named df
#Use a dictionary to specify the columns
df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#View information about a dataframe
#entries means number of rows
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     12 non-null     object
#  1   math     12 non-null     int64
#  2   english  12 non-null     int64
#  3   reading  12 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 512.0+ bytes

# %%
# Summary of numerical values
df.describe()
# Out:
#             math    english    reading
# count  12.000000  12.000000  12.000000
# mean   84.833333  77.666667  86.500000
# std    11.134168  13.371158   9.643651
# min    62.000000  62.000000  67.000000
# 25%    78.500000  63.750000  80.750000
# 50%    90.000000  77.500000  89.000000
# 75%    92.250000  86.750000  93.250000
# max    98.000000  99.000000  98.000000

# %%
#view our data types
df.dtypes
# Out:
# name       object
# math        int64
# english     int64
# reading     int64
# dtype: object

# %%
#Returns (row, count, column count)
df.shape
# Out:
# (12, 4)

# %%
#gives  column names
df.columns
# Out:
# Index(['name', 'math', 'english', 'reading'], dtype='object')

# %%
#gives formation about the index
df.index
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
#Rename columns
df.columns = [col.upper() for col in df.columns]

# %%
df.columns = [col.lower() for col in df.columns]

# %%
#
df [['name', 'math']]
# Out:
#        name  math
# 0     Sally    62
# 1      Jane    88
# 2     Suzie    94
# 3     Billy    98
# 4       Ada    77
# 5      John    79
# 6    Thomas    82
# 7     Marie    93
# 8    Albert    92
# 9   Richard    69
# 10    Isaac    92
# 11     Alan    92

# %%
# select one column
math_scores = df['math']

# %%
type(math_scores)
# Out:
# pandas.core.series.Series

# %%
df['passing_math'] = df.math > 70

# %%
df
# Out:
#        name  math  english  reading  passing_math
# 0     Sally    62       85       80         False
# 1      Jane    88       79       67          True
# 2     Suzie    94       74       95          True
# 3     Billy    98       96       88          True
# 4       Ada    77       92       98          True
# 5      John    79       76       93          True
# 6    Thomas    82       64       81          True
# 7     Marie    93       63       90          True
# 8    Albert    92       62       87          True
# 9   Richard    69       80       94         False
# 10    Isaac    92       99       93          True
# 11     Alan    92       62       72          True

# %%
#multiple methods
df[df.english > 90].sort_values(by='english').head(1).name
# Out:
# 4    Ada
# Name: name, dtype: object

# %%
from pydataset import data

# %%
df
# Out:
#        name  math  english  reading  passing_math
# 0     Sally    62       85       80         False
# 1      Jane    88       79       67          True
# 2     Suzie    94       74       95          True
# 3     Billy    98       96       88          True
# 4       Ada    77       92       98          True
# 5      John    79       76       93          True
# 6    Thomas    82       64       81          True
# 7     Marie    93       63       90          True
# 8    Albert    92       62       87          True
# 9   Richard    69       80       94         False
# 10    Isaac    92       99       93          True
# 11     Alan    92       62       72          True

# %%
df = df.drop(columns=['passing_math'])

# %%
df
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %%
df['passing_english'] = df.english > 70

# %%
# 1a create a column named passing english
# 1b, duplicates are grouped together
df
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True
# 11     Alan    92       62       72            False

# %%
#1c sort by failing/not failing, then name
df.sort_values(by=['passing_english', 'name'])
# Out:
#        name  math  english  reading  passing_english
# 11     Alan    92       62       72            False
# 8    Albert    92       62       87            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True
# 1      Jane    88       79       67             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 2     Suzie    94       74       95             True

# %%
#1b, duplicates are grouped together
#1d sort by grade number then name
df.sort_values(by=['passing_english','english'])
# Out:
#        name  math  english  reading  passing_english
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 2     Suzie    94       74       95             True
# 5      John    79       76       93             True
# 1      Jane    88       79       67             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True

# %%
## 1e add overall grade column and grade

overall_grade = list((df.math + df.english + df.reading)/3)

# %%
overall_grade
# Out:
# [75.66666666666667,
#  78.0,
#  87.66666666666667,
#  94.0,
#  89.0,
#  82.66666666666667,
#  75.66666666666667,
#  82.0,
#  80.33333333333333,
#  81.0,
#  94.66666666666667,
#  75.33333333333333]

# %%
df['overall_grade'] = overall_grade
## or you could do:
df['overall_grade'] = (df['math']+df['english']+df['reading'])

# %% [markdown]
# round(overall_grade)

# %%
#1e overall grade with average
df
# Out:
#        name  math  english  reading  passing_english  overall_grade
# 0     Sally    62       85       80             True            227
# 1      Jane    88       79       67             True            234
# 2     Suzie    94       74       95             True            263
# 3     Billy    98       96       88             True            282
# 4       Ada    77       92       98             True            267
# 5      John    79       76       93             True            248
# 6    Thomas    82       64       81            False            227
# 7     Marie    93       63       90            False            246
# 8    Albert    92       62       87            False            241
# 9   Richard    69       80       94             True            243
# 10    Isaac    92       99       93             True            284
# 11     Alan    92       62       72            False            226

# %%
mpg = data('mpg')

# %%
data('mpg', show_doc=True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
#2 How many rows, columns? 11 columns, and 234 rows
# what are the data types of each column? name is object, math, enlgish and reading are int, passing_english is bool, and overall_grade is float
df.dtypes
# Out:
# name               object
# math                int64
# english             int64
# reading             int64
# passing_english      bool
# overall_grade       int64
# dtype: object

# %%
mpg.info
# Out:
# <bound method DataFrame.info of     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ...

# %%
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
#rename cty to city and hwy to highway
mpg = mpg.rename(columns={'cty':'city'})
mpg = mpg.rename(columns={'hwy':'highway'})

# %%
mpg.dtypes
# Out:
# manufacturer     object
# model            object
# displ           float64
# year              int64
# cyl               int64
# trans            object
# drv              object
# city              int64
# highway           int64
# fl               object
# class            object
# dtype: object

# %%
mpg[['city','highway']]
# Out:
#      city  highway
# 1      18       29
# 2      21       29
# 3      20       31
# 4      21       30
# 5      16       26
# ..    ...      ...
# 230    19       28
# 231    21       29
# 232    16       26
# 233    18       26
# 234    17       26
#
# [234 rows x 2 columns]

# %%
mpg['city better than highway'] = mpg.city > mpg.highway

# %%
mpg.sort_values(by='city better than highway')
#no, there are no cars that have better city milage than highway
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  city  \
# 1           audi                   a4    1.8  1999    4    auto(l5)   f    18
# 149       nissan               maxima    3.0  1999    6  manual(m5)   f    19
# 150       nissan               maxima    3.5  2008    6    auto(av)   f    19
# 151       nissan       pathfinder 4wd    3.3  1999    6    auto(l4)   4    14
# 152       nissan       pathfinder 4wd    3.3  1999    6  manual(m5)   4    15
# ..           ...                  ...    ...   ...  ...         ...  ..   ...
# 84          ford      f150 pickup 4wd    4.2  1999    6    auto(l4)   4    14
# 85          ford      f150 pickup 4wd    4.2  1999    6  manual(m5)   4    14
# 86          ford      f150 pickup 4wd    4.6  1999    8  manual(m5)   4    13
# 74         dodge  ram 1500 pickup 4wd    5.9  1999    8    auto(l4)   4    11
# 234   volkswagen               passat    3.6  2008    6    auto(s6)   f    17
#
# ...

# %%
mpg['milage_difference'] = mpg.highway - mpg.city

# %%
mpg
# column added milage_difference
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %%
mpg.milage_difference.max()
# Out:
# 12

# %%
##or 
mpg.sort_values("milage_difference").tail()
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  city  highway  \
# 106        honda       civic    1.8  2008    4    auto(l5)   f    25       36
# 213   volkswagen       jetta    1.9  1999    4  manual(m5)   f    33       44
# 1           audi          a4    1.8  1999    4    auto(l5)   f    18       29
# 223   volkswagen  new beetle    1.9  1999    4    auto(l4)   f    29       41
# 107        honda       civic    1.8  2008    4    auto(l5)   f    24       36
#
#     fl       class  city better than highway  milage_difference
# 106  r  subcompact                     False                 11
# 213  d     compact                     False                 11
# 1    p     compact                     False                 11
# 223  d  subcompact                     False                 12
# 107  c  subcompact                     False                 12

# %%
lowest_difference = mpg[mpg['milage_difference'] == 12]

# %%
lowest_difference ## cars with highest difference
# Out:
#     manufacturer       model  displ  year  cyl     trans drv  city  highway  \
# 107        honda       civic    1.8  2008    4  auto(l5)   f    24       36
# 223   volkswagen  new beetle    1.9  1999    4  auto(l4)   f    29       41
#
#     fl       class  city better than highway  milage_difference
# 107  c  subcompact                     False                 12
# 223  d  subcompact                     False                 12

# %%
#the lowest highway milage, its the same as the car above
mpg.highway.min()
# Out:
# 12

# %%
lowest_highway = mpg[mpg['highway'] == 12]

# %%
lowest_highway #these are the cars with the lowest highway milage
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  city  \
# 55         dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 60         dodge          durango 4wd    4.7  2008    8    auto(l5)   4     9
# 66         dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 70         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
# 127         jeep   grand cherokee 4wd    4.7  2008    8    auto(l5)   4     9
#
#      highway fl   class  city better than highway  milage_difference
# 55        12  e  pickup                     False                  3
# 60        12  e     suv                     False                  3
# 66        12  e  pickup                     False                  3
# 70        12  e  pickup                     False                  3
# 127       12  e     suv                     False                  3

# %%
compact_cars=mpg[mpg["class"] == 'compact']

# %%
compact_cars.highway.min() ##compact car with lowest highway milage
# Out:
# 23

# %%
compact_lowest = compact_cars[compact_cars['highway'] == 23]

# %%
compact_lowest
# Out:
#     manufacturer  model  displ  year  cyl     trans drv  city  highway fl  \
# 220   volkswagen  jetta    2.8  1999    6  auto(l4)   f    16       23  r
#
#        class  city better than highway  milage_difference
# 220  compact                     False                  7

# %%
compact_min = compact_cars.highway.max() ##comp

# %%
compact_min
# Out:
# 44

# %%
low_compact = compact_cars[compact_cars['highway'] == 44]

# %%
low_compact # car with highest highway milage
# Out:
#     manufacturer  model  displ  year  cyl       trans drv  city  highway fl  \
# 213   volkswagen  jetta    1.9  1999    4  manual(m5)   f    33       44  d
#
#        class  city better than highway  milage_difference
# 213  compact                     False                 11

# %%
average_milage = (mpg.city + mpg.highway) /2

# %%
mpg['average_milage'] = list(average_milage)

# %%
mpg #showing table with average_milage
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %%
dodge_cars = mpg[mpg['manufacturer'] == 'dodge']

# %%
dodge_cars.sort_values('average_milage').head() #dodge cars with lowest average milage
# Out:
#    manufacturer                model  displ  year  cyl       trans drv  city  \
# 70        dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
# 66        dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 60        dodge          durango 4wd    4.7  2008    8    auto(l5)   4     9
# 55        dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 74        dodge  ram 1500 pickup 4wd    5.9  1999    8    auto(l4)   4    11
#
#     highway fl   class  city better than highway  milage_difference  \
# 70       12  e  pickup                     False                  3
# 66       12  e  pickup                     False                  3
# 60       12  e     suv                     False                  3
# 55       12  e  pickup                     False                  3
# 74       15  r  pickup                     False                  4
#
#     average_milage
# 70            10.5
# 66            10.5
# 60            10.5
# ...

# %%
dodge_cars.sort_values('average_milage').tail() 


#dodge cars with highest average milage
# Out:
#    manufacturer        model  displ  year  cyl     trans drv  city  highway  \
# 48        dodge  caravan 2wd    4.0  2008    6  auto(l6)   f    16       23
# 43        dodge  caravan 2wd    3.3  2008    6  auto(l4)   f    17       24
# 42        dodge  caravan 2wd    3.3  2008    6  auto(l4)   f    17       24
# 39        dodge  caravan 2wd    3.0  1999    6  auto(l4)   f    17       24
# 38        dodge  caravan 2wd    2.4  1999    4  auto(l3)   f    18       24
#
#    fl    class  city better than highway  milage_difference  average_milage
# 48  r  minivan                     False                  7            19.5
# 43  r  minivan                     False                  7            20.5
# 42  r  minivan                     False                  7            20.5
# 39  r  minivan                     False                  7            20.5
# 38  r  minivan                     False                  6            21.0

# %%
mammals = data('Mammals')

# %%
mammals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   weight    107 non-null    float64
#  1   speed     107 non-null    float64
#  2   hoppers   107 non-null    bool
#  3   specials  107 non-null    bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB

# %%
mammals.describe() ##3 summarize
# Out:
#             weight       speed
# count   107.000000  107.000000
# mean    278.688178   46.208411
# std     839.608269   26.716778
# min       0.016000    1.600000
# 25%       1.700000   22.500000
# 50%      34.000000   48.000000
# 75%     142.500000   65.000000
# max    6000.000000  110.000000

# %%
mammals.dtypes
# Out:
# weight      float64
# speed       float64
# hoppers        bool
# specials       bool
# dtype: object

# %%
mammals.speed.max()
# Out:
# 110.0

# %%
mammals[mammals["speed"] == 110.0] ##the weight of the fastest animal is
55
# Out:
# 55

# %%
specials = len((mammals[mammals["specials"]==True]))

# %%
total = len(mammals[mammals["specials"]==False])

# %%
percentage_specials = specials / (specials + total)

# %%
percentage_specials*100 ##this is the percentage of specials
# Out:
# 9.345794392523365

# %%
median_1 = mammals.speed.median()

# %%
median_1
# Out:
# 48.0

# %%
hoppers =  mammals[mammals["hoppers"] == True]

# %%
over_median = hoppers[hoppers["speed"] > 48 ]

# %%
len(over_median) #gives number of animals that are hoppers and above median
# Out:
# 7

# %%
(len(over_median) / len(mammals)) * 100 ##percentage of animals
# Out:
# 6.5420560747663545
